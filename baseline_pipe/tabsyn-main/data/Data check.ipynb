# %%
import pandas as pd 
import json
import numpy as np

# %%
df = pd.read_csv("atach50/df50.csv")

# %%
df.columns
# Out:
# Index(['treatment', 'age', 'mRS score after 90 days',
#        'mRS score after 30 days', 'adverse events', 'ICH volume',
#        'ICH Location', 'IVH volume', 'GCS score', 'NIHSS score',
#        'Systolic blood pressure', 'Diastolic Blood Pressure', 'Hypertension',
#        'Hyperlipidemia', 'Type I Diabetes', 'Type II Diabetes',
#        'Congestive heart failure', 'Atrial Fibrillation', 'PTCA',
#        'Peripheral Vascular Disease', 'Myocardial fraction', 'Anti-diabetic',
#        'Antihypertensives', 'White blood count', 'Hemoglobin', 'Hematocrit',
#        'Platelet count', 'APTT', 'INR', 'Glucose', 'Sodium', 'Potassium',
#        'Chloride', 'CD', 'Blood urea nitrogen', 'Creatinine', 'race', 'sex',
#        'ethnicity'],
#       dtype='object')

# %%
df.head()
# Out:
#    treatment   age  mRS score after 90 days  mRS score after 30 days  \
# 0          1  68.0                      4.0                      4.0
# 1          0  65.0                      2.0                      3.0
# 2          0  41.0                      1.0                      2.0
# 3          0  60.0                      3.0                      3.0
# 4          1  55.0                      2.0                      3.0
#
#    adverse events  ICH volume     ICH Location  IVH volume  GCS score  \
# 0               0    14.91285  R Basal Ganglia         0.0       15.0
# 1               0    14.91115  R Basal Ganglia         0.0       14.0
# 2               0     4.00650       L Thalamus         0.0       15.0
# 3               0     3.06625  L Basal Ganglia         0.0       15.0
# 4               0     3.38792       R Thalamus         0.0       15.0
#
#    NIHSS score  ...  Glucose  Sodium  Potassium  Chloride    CD  \
# ...

# %%
x_cols = ['treatment', 'age', 'ICH volume',
       'ICH Location', 'IVH volume', 'GCS score', 'NIHSS score',
       'Systolic blood pressure',
       'Diastolic Blood Pressure',
       'Hypertension', 'Hyperlipidemia',
       'Type I Diabetes', 'Type II Diabetes',
       'Congestive heart failure', 'Atrial Fibrillation',
       'PTCA',
       'Peripheral Vascular Disease',
       'Myocardial fraction', 'Anti-diabetic',
       'Antihypertensives', 'White blood count', 'Hemoglobin',
       'Hematocrit', 'Platelet count', 'APTT', 'INR', 'Glucose', 'Sodium',
       'Potassium', 'Chloride', 'CD', 'Blood urea nitrogen', 'Creatinine',
       'race', 'sex', 'ethnicity']
y_col = 'mRS score after 30 days'

cols = x_cols + [y_col]

# %%
df = df[cols].copy()
df.to_csv("atach50/df50.csv", index=False)

# %%
df50_test = pd.read_csv("atach50/df50_test.csv")
df50_test = df50_test[cols]
df50_test.head()
# Out:
#    treatment   age  ICH volume     ICH Location  IVH volume  GCS score  \
# 0          1  58.0    11.00301  R Basal Ganglia     0.00000       15.0
# 1          1  39.0    21.55289       L Thalamus     0.00391       14.0
# 2          1  62.0     5.60495  L Basal Ganglia     0.00000       15.0
# 3          0  51.0    36.85009  R Basal Ganglia     0.00000       14.0
# 4          1  48.0    26.55593  L Basal Ganglia     0.00000       13.0
#
#    NIHSS score  Systolic blood pressure  Diastolic Blood Pressure  \
# 0         14.0                    181.0                      85.0
# 1         19.0                    143.0                      67.0
# 2         10.0                    145.0                      68.0
# 3         12.0                    201.0                     138.0
# 4         18.0                    183.0                      88.0
#
#    Hypertension  ...  Sodium  Potassium  Chloride    CD  Blood urea nitrogen  \
# ...

# %%
df50_test.to_csv("atach50/df50_test.csv", index=False)

# %%
df25 = pd.read_csv("atach25/df25.csv")
df25 = df25[cols]
df25.to_csv("atach25/df25.csv", index=False)

# %%
df25_test = pd.read_csv("atach25/df25_test.csv")
df25_test = df25_test[cols]
df25_test.to_csv("atach25/df25_test.csv", index=False)

# %% [markdown]
# # ERICH

# %%
df = pd.read_csv("erich25/df25.csv")

# %%
df.head()
# Out:
#    mRS score after 90 days  sex   age      race  ICH volume  IVH volume  \
# 0                      4.0    1  50.0  Hispanic       7.648       0.000
# 1                      4.0    0  78.0     White       3.184       5.626
# 2                      4.0    1  62.0     Black      38.715      18.533
# 3                      3.0    0  75.0  Hispanic       3.286       0.000
# 4                      1.0    1  43.0     Black      12.234       0.000
#
#         ICH location  GCS score  Systolic blood pressure  \
# 0        L Putaminal       12.0                    179.0
# 1  L Caudate Nucleus       15.0                    129.0
# 2        R Putaminal       15.0                    234.0
# 3          R Frontal       10.0                    120.0
# 4        L Putaminal        7.0                    162.0
#
#    Diastolic blood pressure  ...  PTCA  Myocardial infraction  anti-diabetic  \
# 0                     105.0  ...     0                      0              0
# ...

# %%
x_cols = ['sex', 'age', 'race', 'ICH volume', 'IVH volume',
       'ICH location', 'GCS score', 'Systolic blood pressure',
       'Diastolic blood pressure', 'Hypertension', 'Hyperlipidemia',
       'Type 2 diabetes', 'Type 1 diabetes', 'Atrial Fibrillation',
       'Congestive Heart Failure', 'Vascular disease', 'Cocaine use', 'Smoke',
       'PTCA', 'Myocardial infraction', 'anti-diabetic', 'Anti-hypertensives',
       'White blood cell count', 'Hemoglobin', 'Platelet count', 'APTT', 'INR',
       'Glucose']
y_col = 'mRS score after 90 days'
cols = x_cols + [y_col]

# %%
df = df[cols]

# %%
df.to_csv("erich25/df25.csv", index=False)

# %%
df25_test = pd.read_csv("erich25/df25_test.csv")

# %%
df25_test = df25_test[cols]
df25_test.to_csv("erich25/df25_test.csv", index=False)

# %%
df50 = pd.read_csv("erich50/df50.csv")
df50 = df50[cols]
df50.to_csv("erich50/df50.csv", index=False)

# %%
df50_test = pd.read_csv("erich50/df50_test.csv")
df50_test = df50_test[cols]
df50_test.to_csv("erich50/df50_test.csv", index=False)
